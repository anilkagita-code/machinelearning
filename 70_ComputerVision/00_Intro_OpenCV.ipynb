# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import cv2

# %% [markdown]
# ##### Generating a Gray Scale Image

# %%
gen_img = np.arange(100*256).reshape(100, 256)
gen_img = gen_img % 256
gen_img
# Out:
# array([[  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        ...,
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255]], dtype=int32)

# %%
plt.imshow(gen_img, cmap='gray')

# %% [markdown]
# ### Processing a Gray Scale Image

# %%
cameraman_img = cv2.imread('data/cameraman_gray.jpg', cv2.IMREAD_GRAYSCALE)
cameraman_img.shape
# Out:
# (512, 512)

# %%
plt.imshow(cameraman_img, cmap='gray')

# %%
type(cameraman_img), cameraman_img.dtype
# Out:
# (numpy.ndarray, dtype('uint8'))

# %%
cameraman_img
# Out:
# array([[146, 153, 161, ..., 153, 153, 154],
#        [156, 157, 159, ..., 153, 153, 154],
#        [160, 155, 152, ..., 153, 153, 154],
#        ...,
#        [120, 122, 123, ..., 117, 115, 104],
#        [123, 121, 121, ..., 117, 116, 106],
#        [121, 119, 122, ..., 116, 116, 108]], dtype=uint8)

# %%
cameraman_img[200:250, 100:150] = 255
plt.imshow(cameraman_img, cmap='gray')

# %% [markdown]
# ##### Genreating color mage using numpy

# %%
gen_img = np.expand_dims(np.random.randint(0, 256, (3, 3), dtype=np.uint8), axis=0)
gen_img = np.expand_dims(np.random.randint(0, 256, (3, 3), dtype=np.uint8), axis=0)
gen_img = np.expand_dims(np.random.randint(0, 256, (3, 3), dtype=np.uint8), axis=0)
gen_img.shape
# Out:
# (1, 3, 3)

# %%
plt.imshow(gen_img)

# %%
cameraman_img = cv2.imread('data/cameraman.jpg', cv2.COLOR_BAYER_BG2RGB)

# %%
cameraman_img
