# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_piece = pd.read_csv('data/Piece_Dim.csv')

# %%
df_piece.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %% [markdown]
# ## Histogram

# %%
plt.hist(x=df_piece['Length'])
plt.show()

# %%
plt.hist(x=df_piece['Length'], bins=20, histtype='bar')
plt.show()

# %% [markdown]
# ## Box plot

# %%
plt.boxplot(x=df_piece['Length'])
plt.show()

# %%
# Box plot duing the DataFrame
df_piece.boxplot(column=['Length'], by=['Operator'])
plt.tight_layout()
plt.show()

# %%
# Box plot duing the DataFrame
df_piece.boxplot(column=['Length', 'Width'], by=['Operator'])
plt.tight_layout()
plt.show()

# %%
# Box plot duing the DataFrame
df_piece.boxplot(column=['Length'], by=['Operator'], notch=True)
plt.tight_layout()
plt.show()

# %%
plt.violinplot(df_piece['Length'])
plt.show()

# %%
df_piece.boxplot(column=['Length', 'Width'], by='Operator', layout=(1, 2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line Plot

# %%
plt.plot(df_piece['Length'])
plt.show()

# %%
plt.plot(df_piece['Length'])
len_mean = df_piece['Length'].mean()
len_std = df_piece['Length'].std()
plt.axhline(y=len_mean, color=[1, 0, 0, .75], linestyle='-', label='mean')
plt.axhline(y=len_mean+1.5*len_std, color=[0, 0, 1, .75], linestyle='--', label='1.5_Std')
plt.axhline(y=len_mean-1.5*len_std, color=[0, 0, 1, .75], linestyle=':', label='-1.5_Std')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x=df_piece['Length'], y=df_piece['Width'])
plt.show()

# %%
plt.scatter(x=df_piece['Length'], y=df_piece['Width'], marker='v')
plt.show()

# %%
plt.scatter(x=df_piece['Length'], y=df_piece['Width'], s=df_piece['Height'])
plt.show()

# %% [markdown]
# ## Bar plots
# Need to work on this more

# %%
plt.bar(x=df_piece['Length'], height=df_piece['Length'].count())
plt.plot()
# Out:
# []

# %%
df_piece.plot(kind='bar', x='Operator', y='Length', figsize=(12,9))
# Out:
# <AxesSubplot:xlabel='Operator'>

# %% [markdown]
# ## Saving the Plots

# %%
plt.scatter(x=df_piece['Length'], y=df_piece['Width'], marker='v')
plt.savefig('scatterPlot.jpg')

# %%
plt.scatter(x=df_piece['Length'], y=df_piece['Width'], marker='v')
plt.savefig('scatterPlot_300.jpg', dpi=300)
